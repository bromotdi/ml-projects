# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### _Data Understanding_

# %%
data = pd.read_csv('Dataset_poems.csv',index_col=None)
data.head()
# Out:
#                                     author  \
# 0                      WILLIAM SHAKESPEARE
# 1  DUCHESS OF NEWCASTLE MARGARET CAVENDISH
# 2                           THOMAS BASTARD
# 3                           EDMUND SPENSER
# 4                        RICHARD BARNFIELD
#
#                                              content  \
# 0  Let the bird of loudest lay\r\nOn the sole Ara...
# 1  Sir Charles into my chamber coming in,\r\nWhen...
# 2  Our vice runs beyond all that old men saw,\r\n...
# 3  Lo I the man, whose Muse whilome did maske,\r\...
# 4  Long have I longd to see my love againe,\r\nSt...
#
#                                  poem name          age                  type
# 0               The Phoenix and the Turtle  Renaissance  Mythology & Folklore
# 1                 An Epilogue to the Above  Renaissance  Mythology & Folklore
# 2                       Book 7, Epigram 42  Renaissance  Mythology & Folklore
# 3  from The Faerie Queene: Book I, Canto I  Renaissance  Mythology & Folklore
# 4                                Sonnet 16  Renaissance  Mythology & Folklore

# %%
data = data[data['poem name'].isnull()==False]                   # removing the null values 
data = data[data['content'].isnull()==False]
data.shape
# Out:
# (571, 5)

# %%
data=data[data["content"].str.contains("Copyright")==False]
data.shape
# Out:
# (501, 5)

# %%
data=data[data["content"].str.contains("from Dana, 1904")==False]               # Faulty data ,needed to be removed
data.shape
#data["content"]
# Out:
# (500, 5)

# %% [markdown]
# ### _Data Preparation_

# %%
data.content = data["content"].str.lower()       
data['content'].head()
# Out:
# 0    let the bird of loudest lay\r\non the sole ara...
# 1    sir charles into my chamber coming in,\r\nwhen...
# 2    our vice runs beyond all that old men saw,\r\n...
# 3    lo i the man, whose muse whilome did maske,\r\...
# 4    long have i longd to see my love againe,\r\nst...
# Name: content, dtype: object

# %%
data['content'] = data['content'].str.replace("\n", " ")                #   Remove "#" to observe the updated data 
data['content'] = data['content'].str.replace("\r", " ")
data['content'] = data['content'].str.replace("\t", " ")
data['content'] = data['content'].str.replace(","," ").replace("."," ")
#data['content']

# %%
data['content'] = data['content'].str.replace("[^a-zA-Z]", " ")
data['content'] = data['content'].str.replace("ing( |$)", " ")
data['content'] = data['content'].str.replace("ies( |$)", "y ")
data['content'].head()
# Out:
# 0    let the bird of loudest lay  on the sole arabi...
# 1    sir charles into my chamber com in   when i wa...
# 2    our vice runs beyond all that old men saw   an...
# 3    lo i the man  whose muse whilome did maske   a...
# 4    long have i longd to see my love againe   stil...
# Name: content, dtype: object

# %%
# remove list in the document
remove_list=["A",
"An",
"The",
"Aboard",
"About",
"Above",
"Absent",
"Across",
"After",
"Against",
"Along",
"Alongside",
"Amid",
"Among",
"Amongst",
"Anti",
"Around",
"As",
"At",
"Before",
"Behind",
"Below",
"Beneath",
"Beside",
"Besides",
"Between",
"Beyond",
"But",
"By",
"Circa",
"Concerning",
"Considering",
"Despite",
"Down",
"During",
"Except",
"Excepting",
"Excluding",
"Failing",
"Following",
"For",
"From",
"Given",
"In",
"Inside",
"Into",
"Like",
"Minus",
"Near",
"Of",
"Off",
"On",
"Onto",
"Opposite",
"Outside",
"Over",
"Past",
"Per",
"Plus",
"Regarding",
"Round",
"Save",
"Since",
"Than",
"Through",
"To",
"Toward",
"Towards",
"Under",
"Underneath",
"Unlike",
"Until",
"Up",
"Upon",
"Versus",
"Via",
"With",
"Within",
"Without"]

# %%
for words in remove_list:
    data['content'] = data['content'].str.replace(words , " ")

# %%
X = data.iloc[:,0:3]            # Features
y = data.iloc[:,-1]             # Label

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(ngram_range=(1,1), sublinear_tf=True, analyzer= 'word')

# %%
X_content = vectorizer.fit_transform(X["content"].values)           # X_content is the sparse matrix formed by X["content"]     
feature_names = vectorizer.get_feature_names()                      # Features extracted from X_content storede in feature_names   
len(feature_names)
# Out:
# 10892

# %%
from sklearn import preprocessing                   # Preprocessing the other columns using label encoder
 
label_au = preprocessing.LabelEncoder()
X_author = label_au.fit_transform(X.author.values)

label_poe_name = TfidfVectorizer(analyzer='word', ngram_range=(1,3), min_df = 0, stop_words = 'english')  
X_poemname  = label_poe_name.fit_transform(X["poem name"].values)

X_author = np.reshape(X_author, (X_author.shape[0], 1))

# %%
import scipy.sparse as sp                        # Joining the three formed data to form the final input features

X_final = sp.hstack([X_content,X_author, X_poemname])

# %% [markdown]
# ### _Modelling_
# #### _Classification of poems on the basis of genres , Will use 2 different classifiers_

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(X_final , y , test_size = 0.20 , random_state = 0)
print(X_train.shape)
print(X_test.shape)
# Out:
# (400, 13444)
# (100, 13444)

# %% [markdown]
# ### Classifier-1  (Random Forest)

# %%
from sklearn.ensemble import RandomForestClassifier             

Classifier = RandomForestClassifier(n_estimators = 100 , criterion = "entropy" , random_state = 0)
Classifier.fit(X_train, y_train)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
y_pred = Classifier.predict(X_test)
print(y_test.values)
print(y_pred)
# Out:
# ['Love' 'Love' 'Love' 'Love' 'Love' 'Mythology & Folklore'
#  'Mythology & Folklore' 'Love' 'Love' 'Love' 'Love' 'Love' 'Nature' 'Love'
#  'Love' 'Mythology & Folklore' 'Love' 'Nature' 'Love' 'Nature' 'Love'
#  'Nature' 'Love' 'Love' 'Nature' 'Love' 'Nature' 'Nature' 'Love' 'Love'
#  'Nature' 'Love' 'Love' 'Love' 'Nature' 'Love' 'Love' 'Love' 'Nature'
#  'Love' 'Mythology & Folklore' 'Nature' 'Nature' 'Love' 'Love'
#  'Mythology & Folklore' 'Love' 'Mythology & Folklore' 'Nature' 'Love'
#  'Nature' 'Love' 'Nature' 'Love' 'Love' 'Mythology & Folklore'
#  'Mythology & Folklore' 'Love' 'Love' 'Mythology & Folklore' 'Love' 'Love'
#  'Nature' 'Nature' 'Love' 'Love' 'Mythology & Folklore' 'Love' 'Love'
#  'Love' 'Love' 'Nature' 'Mythology & Folklore' 'Love' 'Love' 'Nature'
#  'Love' 'Love' 'Love' 'Love' 'Love' 'Love' 'Love' 'Love'
#  'Mythology & Folklore' 'Mythology & Folklore' 'Nature' 'Love' 'Nature'
#  'Nature' 'Love' 'Nature' 'Nature' 'Love' 'Love' 'Nature' 'Nature' 'Love'
#  'Nature' 'Love']
# ['Love' 'Love' 'Love' 'Love' 'Nature' 'Nature' 'Love' 'Love' 'Love' 'Love'
#  'Nature' 'Love' 'Nature' 'Love' 'Love' 'Love' 'Love' 'Love' 'Love' 'Love'
#  'Love' 'Love' 'Love' 'Love' 'Love' 'Mythology & Folklore' 'Love' 'Love'
#  'Love' 'Love' 'Nature' 'Love' 'Love' 'Love' 'Love' 'Nature' 'Love'
#  'Nature' 'Nature' 'Love' 'Love' 'Love' 'Love' 'Love' 'Love' 'Love' 'Love'
#  'Nature' 'Love' 'Love' 'Nature' 'Love' 'Nature' 'Love' 'Love' 'Love'
#  'Love' 'Love' 'Love' 'Love' 'Love' 'Love' 'Love' 'Nature' 'Nature' 'Love'
#  'Love' 'Love' 'Love' 'Love' 'Love' 'Nature' 'Love' 'Love' 'Love' 'Love'
#  'Love' 'Love' 'Love' 'Nature' 'Love' 'Love' 'Love' 'Love' 'Nature' 'Love'
#  'Love' 'Love' 'Nature' 'Love' 'Love' 'Love' 'Nature' 'Love' 'Love'
#  'Nature' 'Love' 'Love' 'Mythology & Folklore' 'Love']

# %%
pd.DataFrame({ 'correct_class' : y_test, 
               'Predicted_class' : y_pred,
                }).reset_index()
# Out:
#     index         correct_class       Predicted_class
# 0      90                  Love                  Love
# 1     254                  Love                  Love
# 2     283                  Love                  Love
# 3     508                  Love                  Love
# 4     532                  Love                Nature
# 5      15  Mythology & Folklore                Nature
# 6     316  Mythology & Folklore                  Love
# 7     561                  Love                  Love
# 8     159                  Love                  Love
# 9     153                  Love                  Love
# 10    241                  Love                Nature
# 11    250                  Love                  Love
# 12    429                Nature                Nature
# 13    289                  Love                  Love
# 14    171                  Love                  Love
# 15    336  Mythology & Folklore                  Love
# 16    540                  Love                  Love
# 17    371                Nature                  Love
# 18    154                  Love                  Love
# 19     37                Nature                  Love
# 20    205                  Love                  Love
# 21    384                Nature                  Love
# 22    240                  Love                  Love
# 23    108                  Love                  Love
# 24     45                Nature                  Love
# 25    497                  Love  Mythology & Folklore
# 26     21                Nature                  Love
# 27    386                Nature                  Love
# 28     96                  Love                  Love
# 29    233                  Love                  Love
# ..    ...                   ...                   ...
# 70    142                  Love                  Love
# 71     65                Nature                Nature
# 72    351  Mythology & Folklore                  Love
# 73    556                  Love                  Love
# 74    175                  Love                  Love
# 75    380                Nature                  Love
# 76    264                  Love                  Love
# 77    100                  Love                  Love
# 78    563                  Love                  Love
# 79    295                  Love                Nature
# 80    300                  Love                  Love
# 81    235                  Love                  Love
# 82    547                  Love                  Love
# 83    219                  Love                  Love
# 84    337  Mythology & Folklore                Nature
# 85    327  Mythology & Folklore                  Love
# 86    473                Nature                  Love
# 87    157                  Love                  Love
# 88    363                Nature                Nature
# 89     54                Nature                  Love
# 90    220                  Love                  Love
# 91    448                Nature                  Love
# 92    404                Nature                Nature
# 93    200                  Love                  Love
# 94    179                  Love                  Love
# 95    392                Nature                Nature
# 96     56                Nature                  Love
# 97    499                  Love                  Love
# 98     60                Nature  Mythology & Folklore
# 99    208                  Love                  Love
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Result Evaluation

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test , y_pred)
print(cm)
# Out:
# [[53  1  6]
#  [10  0  3]
#  [16  1 10]]

# %% [markdown]
# ### Classifier 2 : Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
Classifier = GaussianNB()
Classifier.fit(X_train.toarray() , y_train)
# Out:
# GaussianNB(priors=None)

# %%
y_pred = Classifier.predict(X_test.toarray())
print(y_test.values)
print(y_pred)
# Out:
# ['Love' 'Love' 'Love' 'Love' 'Love' 'Mythology & Folklore'
#  'Mythology & Folklore' 'Love' 'Love' 'Love' 'Love' 'Love' 'Nature' 'Love'
#  'Love' 'Mythology & Folklore' 'Love' 'Nature' 'Love' 'Nature' 'Love'
#  'Nature' 'Love' 'Love' 'Nature' 'Love' 'Nature' 'Nature' 'Love' 'Love'
#  'Nature' 'Love' 'Love' 'Love' 'Nature' 'Love' 'Love' 'Love' 'Nature'
#  'Love' 'Mythology & Folklore' 'Nature' 'Nature' 'Love' 'Love'
#  'Mythology & Folklore' 'Love' 'Mythology & Folklore' 'Nature' 'Love'
#  'Nature' 'Love' 'Nature' 'Love' 'Love' 'Mythology & Folklore'
#  'Mythology & Folklore' 'Love' 'Love' 'Mythology & Folklore' 'Love' 'Love'
#  'Nature' 'Nature' 'Love' 'Love' 'Mythology & Folklore' 'Love' 'Love'
#  'Love' 'Love' 'Nature' 'Mythology & Folklore' 'Love' 'Love' 'Nature'
#  'Love' 'Love' 'Love' 'Love' 'Love' 'Love' 'Love' 'Love'
#  'Mythology & Folklore' 'Mythology & Folklore' 'Nature' 'Love' 'Nature'
#  'Nature' 'Love' 'Nature' 'Nature' 'Love' 'Love' 'Nature' 'Nature' 'Love'
#  'Nature' 'Love']
# ['Love' 'Nature' 'Love' 'Nature' 'Mythology & Folklore' 'Nature' 'Love'
#  'Nature' 'Love' 'Love' 'Nature' 'Love' 'Nature' 'Love' 'Love' 'Love'
#  'Love' 'Love' 'Love' 'Nature' 'Love' 'Nature' 'Love' 'Love'
#  'Mythology & Folklore' 'Mythology & Folklore' 'Love' 'Nature' 'Love'
#  'Love' 'Nature' 'Love' 'Love' 'Love' 'Love' 'Nature' 'Love'
#  'Mythology & Folklore' 'Nature' 'Love' 'Nature' 'Love' 'Love' 'Love'
#  'Love' 'Love' 'Love' 'Nature' 'Love' 'Love' 'Nature' 'Love' 'Nature'
#  'Love' 'Love' 'Love' 'Mythology & Folklore' 'Love' 'Love' 'Nature' 'Love'
#  'Love' 'Love' 'Love' 'Nature' 'Love' 'Mythology & Folklore' 'Nature'
#  'Love' 'Love' 'Love' 'Nature' 'Love' 'Nature' 'Love' 'Nature' 'Love'
#  'Love' 'Love' 'Nature' 'Love' 'Love' 'Mythology & Folklore' 'Love'
#  'Nature' 'Nature' 'Nature' 'Love' 'Love' 'Love' 'Love' 'Love'
#  'Mythology & Folklore' 'Love' 'Love' 'Nature' 'Love' 'Nature'
#  'Mythology & Folklore' 'Love']

# %%
pd.DataFrame({ 'correct_class' : y_test, 
               'Predicted_class' : y_pred,
                }).reset_index()
# Out:
#     index         correct_class       Predicted_class
# 0      90                  Love                  Love
# 1     254                  Love                Nature
# 2     283                  Love                  Love
# 3     508                  Love                Nature
# 4     532                  Love  Mythology & Folklore
# 5      15  Mythology & Folklore                Nature
# 6     316  Mythology & Folklore                  Love
# 7     561                  Love                Nature
# 8     159                  Love                  Love
# 9     153                  Love                  Love
# 10    241                  Love                Nature
# 11    250                  Love                  Love
# 12    429                Nature                Nature
# 13    289                  Love                  Love
# 14    171                  Love                  Love
# 15    336  Mythology & Folklore                  Love
# 16    540                  Love                  Love
# 17    371                Nature                  Love
# 18    154                  Love                  Love
# 19     37                Nature                Nature
# 20    205                  Love                  Love
# 21    384                Nature                Nature
# 22    240                  Love                  Love
# 23    108                  Love                  Love
# 24     45                Nature  Mythology & Folklore
# 25    497                  Love  Mythology & Folklore
# 26     21                Nature                  Love
# 27    386                Nature                Nature
# 28     96                  Love                  Love
# 29    233                  Love                  Love
# ..    ...                   ...                   ...
# 70    142                  Love                  Love
# 71     65                Nature                Nature
# 72    351  Mythology & Folklore                  Love
# 73    556                  Love                Nature
# 74    175                  Love                  Love
# 75    380                Nature                Nature
# 76    264                  Love                  Love
# 77    100                  Love                  Love
# 78    563                  Love                  Love
# 79    295                  Love                Nature
# 80    300                  Love                  Love
# 81    235                  Love                  Love
# 82    547                  Love  Mythology & Folklore
# 83    219                  Love                  Love
# 84    337  Mythology & Folklore                Nature
# 85    327  Mythology & Folklore                Nature
# 86    473                Nature                Nature
# 87    157                  Love                  Love
# 88    363                Nature                  Love
# 89     54                Nature                  Love
# 90    220                  Love                  Love
# 91    448                Nature                  Love
# 92    404                Nature  Mythology & Folklore
# 93    200                  Love                  Love
# 94    179                  Love                  Love
# 95    392                Nature                Nature
# 96     56                Nature                  Love
# 97    499                  Love                Nature
# 98     60                Nature  Mythology & Folklore
# 99    208                  Love                  Love
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Result Evaluation

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test , y_pred)
print(cm)
# Out:
# [[46  4 10]
#  [ 5  2  6]
#  [12  3 12]]

# %% [markdown]
# ### Analysis Of the Classifiers Used

# %% [markdown]
# ###### Using Random Forest classifier , we got an accuracy which is around 63% which is below par.
# ###### Using Naive-bayes classifier , we got an accuracy which is around 60% which is very low.
# _We can infer that both classifiers didn't performed well on the test data , thus more training data is required to fit the classifiers well._
